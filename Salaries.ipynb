# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"D:\Downloads\pandas project\pandas project\Salries\Salaries.csv")

# %%
df

# %%
# 1. Display Top 10 Rows of The Dataset 

df.head(10)

# %%
# 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)

# %%
 # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape

# %%
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()

# %%
 # 5. Check Null Values In The Dataset

# %%
df.isnull().sum()

# %%
# 6. Drop ID, Notes, Agency, and Status Columns

# %%
drop_col=df[['Id','Notes','Agency','Status']]

# %%
df=df.drop(columns=drop_col)

# %%
df.shape

# %%
# 7. Get Overall Statistics About The Dataframe

# %%
df.describe()

# %%
# 8. Find Occurrence of The Employee Names (Top 5)

# %%
df['EmployeeName'].value_counts().head(5).reset_index()

# %%
# 9. Find The Number of Unique Job Titles

# %%
df['JobTitle'].unique().size

# %%
# 10.Total Number of Job Titles Contain Captain

# %%
df[df['JobTitle'].str.contains('Captain')]

# %%
# 11. Display All the Employee Names From Fire Department

# %%
df[df['JobTitle'].str.contains('Fire Department')][['EmployeeName','JobTitle']]

# %%
# 12. Find Minimum, Maximum, and Average BasePay

# %%
df['BasePay'] = (
    pd.to_numeric(df['BasePay'], errors='coerce')  # convert safely
    .fillna(0)                                     # replace NaN
    .round()                                       # handle decimals
    .astype('int64')                               # convert to int
)

# %%
df.dtypes

# %%
df['BasePay'].min()

# %%
df['BasePay'].max()

# %%
df['BasePay'].mean()

# %%
# 13. Replace 'Not Provided' in EmployeeName' Column to NaN

# %%
df['EmployeeName']=df['EmployeeName'].replace('Not provided',np.nan)

# %%
df['EmployeeName']

# %%
# 14. Drop The Rows Having 5 Missing Values

# %%
drop_varr=(df[df.isnull().sum(axis=1)==5])

# %%
# 15. Find Job Title of ALBERT PARDINI

# %%
df[df['EmployeeName']=='ALBERT PARDINI']['JobTitle']

# %%
# 16. How Much ALBERT PARDINI Make (Include Benefits)?

df['Benefits']=df['Benefits'].fillna(0)

# %%
df.dtypes

# %%
df['OvertimePay']=pd.to_numeric(df['OvertimePay'],errors='coerce').fillna(0).round().astype('int64')

# %%
df['OtherPay']=pd.to_numeric(df['OtherPay'],errors='coerce').fillna(0).round().astype('int64')

# %%
df['Benefits']=pd.to_numeric(df['Benefits'],errors='coerce').fillna(0).round().astype('int64')

# %%
df.dtypes

# %%
df['TotalNew']=df['TotalPay']+df['Benefits']
df['TotalNew']

# %%
 # 17.Display Name of The Person Having The Highest BasePay

df.sort_values(by='BasePay',ascending=False)[['EmployeeName','BasePay']].head(1)

# %%
#  18.Find Average BasePay of All Employee Per Year    

df.groupby(['Year'])['BasePay'].mean()

# %%
# 19. Find Average BasePay of All Employee Per JobTitle

df.groupby(['JobTitle'])['BasePay'].mean()

# %%
# 20. Find Average BasePay of Employee Having Job Title ACCOUNTANT 

df.groupby('JobTitle').get_group('ACCOUNTANT')['BasePay'].mean()


# OR

# %%
df[df['JobTitle']=='ACCOUNTANT']['BasePay'].mean()

# %%
# 21. Find Top 5 Most Common Jobs

df['JobTitle'].value_counts().head(5)
